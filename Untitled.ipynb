# %%
import pandas as pd

# %%
data = pd.read_json('pet.json',lines=True)

# %%
data.head()
# Out:
#              category                          pluscode        lat  \
# 0        Sykkelbutikk              WVMJ+QG Oslo, Norway  10.881359
# 1        Sykkelbutikk              WVMJ+QG Oslo, Norway  10.881359
# 2                             GV63+X6 Haugastøl, Norway   7.853090
# 3                      RX34+J4 Gol Municipality, Norway   8.955284
# 4  Aktivitetsarrangør            3CHF+42 Færder, Norway  10.422542
#
#                                              address          tel        lon  \
# 0                Jerikoveien 18 , 1067 Oslo , Norway  +4790706060  59.934495
# 1                Jerikoveien 18 , 1067 Oslo , Norway  +4797026277  59.934495
# 2                            3595 Haugastøl , Norway  +4732087564  60.512393
# 3  Einarsetvegen 401 , 3550 Gol i Hallingdal , No...  +4732078000  60.804072
# 4                 Sjøbusand 62 , 3145 Tjøme , Norway  +4797142512  59.077842
#
#                         website  \
# 0  http://www.oslo-elsykkel.no/
# 1
# ...

# %%
data.to_csv("data.csv")

# %%
import sys
import pandas as pd

json_file = sys.argv[1]
csv_name = sys.argv[2]

def json_to_csv(json_file,csv_name = None):
    """Function to convert json file to csv file
    
    Parameters:
    json_file(str): This is the file name of the json file you want to convert.It should include the file extension(.json)
    csv_name(str): This is the name of the output csv file
    
    Returns:
    A converted csv file in the current directory
    A data frame object
    """
    data_df = pd.read_json(json_file,lines = True)
    if csv_name == None:
        csv_name = 'converted_file'
    data_df.to_csv(f'{csv_name}.csv')
    return data_df

json_to_csv(json_file,csv_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ce74d6b7373f> in <module>
#      22     return data_df
#      23
# ---> 24 json_to_csv(json_file,csv_name)
#
# <ipython-input-14-ce74d6b7373f> in json_to_csv(json_file, csv_name)
#      16     A data frame object
#      17     """
# ---> 18     data_df = pd.read_json(json_file,lines = True)
#      19     if csv_name == None:
#      20         csv_name = 'converted_file'
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ...

# %%
json_to_csv('pet.json')
# Out:
#                             category                          pluscode  \
# 0                       Sykkelbutikk              WVMJ+QG Oslo, Norway
# 1                       Sykkelbutikk              WVMJ+QG Oslo, Norway
# 2                                            GV63+X6 Haugastøl, Norway
# 3                                     RX34+J4 Gol Municipality, Norway
# 4                 Aktivitetsarrangør            3CHF+42 Færder, Norway
# ...                              ...                               ...
# 29747                                     RWGC+HR Tain, United Kingdom
# 29748                                         FH4R+W7 Markaryd, Sweden
# 29749  Telecommunications contractor        CX44+P9 Sollentuna, Sweden
# 29750                      Fabrikant      3VGV+G6 Woerden, Netherlands
# 29751       Almennyttig organisation
#
#              lat                                            address  \
# 0      10.881359                Jerikoveien 18 , 1067 Oslo , Norway
# ...

# %%
t= "1"

# %%
type(t)
# Out:
# str
